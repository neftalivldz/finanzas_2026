# %%
from backtesting import PortfolioBacktester

bt = PortfolioBacktester(
        portfolio_path="portfolio.json",
        start_date="2023-01-03",
    )
pv = bt.run()
# Out:
# Downloading AAPL.O data from 2023-01-03 to 2026-03-11...
# Successfully downloaded 799 records
# Downloading AMZN.O data from 2023-01-03 to 2026-03-11...
# Successfully downloaded 798 records
# Downloading NVDA.O data from 2023-01-03 to 2026-03-11...
# Successfully downloaded 798 records
# Downloading MSFT.O data from 2023-01-03 to 2026-03-11...
# Successfully downloaded 799 records
# Downloading GOOGL.O data from 2023-01-03 to 2026-03-11...
# Successfully downloaded 798 records
# Downloading KO data from 2023-01-03 to 2026-03-11...
# Successfully downloaded 798 records
# Downloading NOC.N data from 2023-01-03 to 2026-03-11...
# Successfully downloaded 798 records
# Downloading PBR.N data from 2023-01-03 to 2026-03-11...
# Successfully downloaded 799 records
# Downloading C data from 2023-01-03 to 2026-03-11...
# Successfully downloaded 798 records
# Downloading BIMBOA.MX data from 2023-01-03 to 2026-03-11...
# Successfully downloaded 799 records

# %%
print(pv.head())
print(f"\nValor final del portafolio: ${pv['portfolio_value'].iloc[-1]:,.2f}")
# Out:
#             portfolio_value
# Date
# 2023-01-03       108069.675
# 2023-01-04       103757.571
# 2023-01-05       100897.165
# 2023-01-06       102153.881
# 2023-01-09       103129.002
#
# Valor final del portafolio: $195,996.71

# %%
bt.plot()

# %%
bt.plot()
