# %%
#%pip install lseg.data

# %%
from stock_price_downloader import StockPriceDownloader

# %%
# Crear instancia
downloader = StockPriceDownloader('AAPL', '2022-01-01')
# Descargar datos
downloader.download_data()
# Obtener estadísticas
stats = downloader.get_statistics()
downloader.print_statistics()
# Análisis por año
downloader.print_yearly_analysis()
# Visualizar
downloader.plot_closing_prices()
# Exportar
downloader.export_to_csv('output.csv')

# %%
# Crear instancia
aapl = StockPriceDownloader('AAPL', '2022-01-01')
# Descargar datos
df_aapl = aapl.download_data()

df_aapl
# Out:
# Downloading AAPL data from 2022-01-01 to 2026-02-19...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/app/finanzas_2026/stock_price_downloader.py:110, in StockPriceDownloader.download_data(self)
#     105 ld = self.get_session()
#     107 self.data = ld.get_history(
#     108     universe=[self.ticker],
#     109     fields=['TR.PriceClose', 'TR.PriceOpen', 'TR.PriceHigh', 'TR.PriceLow', 'TR.Volume'],
# --> 110     interval=self.interval_period,
#     111     start = self.start_date,
#     112     end = self.end_date)
#     114 if self.data.empty:
#
# AttributeError: 'StockPriceDownloader' object has no attribute 'interval_period'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 aapl = StockPriceDownloader('AAPL', '2022-01-01')
#       3 # Descargar datos
# ----> 4 df_aapl = aapl.download_data()
#       6 df_aapl
#
# File ~/app/finanzas_2026/stock_price_downloader.py:125, in StockPriceDownloader.download_data(self)
#     122     return self.data
#     124 except Exception as e:
# --> 125     raise Exception(f"Failed to download data: {e}")
#
# Exception: Failed to download data: 'StockPriceDownloader' object has no attribute 'interval_period'

# %%
aapl.plot_closing_prices()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 aapl.plot_closing_prices()
#
# File ~/app/finanzas_2026/stock_price_downloader.py:290, in StockPriceDownloader.plot_closing_prices(self, figsize, show_average, save_path)
#     282 if show_average:
#     283     avg_price = self.closing_prices.mean()
#     284     plt.axhline(
#     285         y=avg_price,
#     286         color='red',
#     287         linestyle='--',
#     288         linewidth=1.5,
#     289         alpha=0.7,
# --> 290         label=f'Average: ${avg_price:.2f}'
#     291     )
#     293 plt.title(
#     294     f'{self.ticker} Closing Prices ({self.start_date} to {self.end_date})',
#     295     fontsize=18,
#     296     fontweight='bold',
#     297     pad=20
#     298 )
#     299 plt.xlabel('Date', fontsize=14, fontweight='bold')
#
# TypeError: unsupported format string passed to Series.__format__

# %%
# Crear instancia
amzn = StockPriceDownloader('AMZN', '2022-01-01')
# Descargar datos
df_amzn = amzn.download_data()

df_amzn
# Out:
# Downloading AMZN data from 2022-01-01 to 2026-02-16...
# Successfully downloaded 1033 records
# Price            Close        High         Low        Open    Volume
# Ticker            AMZN        AMZN        AMZN        AMZN      AMZN
# Date
# 2022-01-03  170.404495  170.703506  166.160507  167.550003  63520000
# 2022-01-04  167.522003  171.399994  166.349503  170.438004  70726000
# 2022-01-05  164.356995  167.126495  164.356995  166.882996  64302000
# 2022-01-06  163.253998  164.800003  161.936996  163.450500  51958000
# 2022-01-07  162.554001  165.243500  162.031006  163.839005  46606000
# ...                ...         ...         ...         ...       ...
# 2026-02-09  208.720001  212.809998  203.350006  208.970001  91178400
# 2026-02-10  206.960007  212.649994  206.410004  208.800003  67175000
# 2026-02-11  204.080002  208.570007  202.490005  208.059998  65545500
# 2026-02-12  199.600006  203.960007  197.559998  203.960007  83975400
# 2026-02-13  198.789993  201.160004  197.279999  198.880005  66215800
#
# [1033 rows x 5 columns]

# %%
amzn.plot_closing_prices()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 amzn.plot_closing_prices()
#
# File ~/app/finanzas_2026/stock_price_downloader.py:290, in StockPriceDownloader.plot_closing_prices(self, figsize, show_average, save_path)
#     282 if show_average:
#     283     avg_price = self.closing_prices.mean()
#     284     plt.axhline(
#     285         y=avg_price,
#     286         color='red',
#     287         linestyle='--',
#     288         linewidth=1.5,
#     289         alpha=0.7,
# --> 290         label=f'Average: ${avg_price:.2f}'
#     291     )
#     293 plt.title(
#     294     f'{self.ticker} Closing Prices ({self.start_date} to {self.end_date})',
#     295     fontsize=18,
#     296     fontweight='bold',
#     297     pad=20
#     298 )
#     299 plt.xlabel('Date', fontsize=14, fontweight='bold')
#
# TypeError: unsupported format string passed to Series.__format__
