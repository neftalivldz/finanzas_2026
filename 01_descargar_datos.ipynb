# %%
#%pip install lseg.data

# %%
from stock_price_downloader import StockPriceDownloader

# %%
# Crear instancia
downloader = StockPriceDownloader('AAPL.O', '2022-01-01')
# Descargar datos
downloader.download_data()
# Obtener estadísticas
stats = downloader.get_statistics()
downloader.print_statistics()
# Análisis por año
downloader.print_yearly_analysis()
# Visualizar
downloader.plot_closing_prices()
# Exportar
#downloader.export_to_csv('output.csv')
# Out:
# ...
# Successfully downloaded 1036 records
#
# ...
# STATISTICS FOR AAPL.O
# ...
#
# Period: 2022-01-01 to 2026-02-19
# Total records: 1036
#
# Price Range:
#   Maximum: $286.19 on 2025-12-02
#   Minimum: $125.02 on 2023-01-05
#   Average: $193.95
#   Std Dev: $38.33
#
# Current Status:
#   Initial Price: $182.01
#   Current Price: $260.58 (2026-02-19)
#   Total Change: +43.17%
# ...
#
#
# ...
# YEARLY ANALYSIS
# ...
#
# 2022:
#   Initial: $182.01
#   Final: $129.93
#   Change: -28.61%
#   Max: $182.01
#   Min: $126.04
#   Average: $154.84
#
# 2023:
#   Initial: $125.07
#   Final: $192.53
#   Change: +53.94%
#   Max: $198.11
#   Min: $125.02
#   Average: $172.55
#
# 2024:
#   Initial: $185.64
#   Final: $250.42
#   Change: +34.90%
#   Max: $259.02
#   Min: $165.00
#   Average: $207.21
#
# 2025:
#   Initial: $243.85
#   Final: $271.86
#   Change: +11.49%
#   Max: $286.19
#   Min: $172.42
#   Average: $232.24
#
# 2026:
#   Initial: $271.01
#   Final: $260.58
#   Change: -3.85%
#   Max: $278.12
#   Min: $246.70
# ...

# %%
# Crear instancia
aapl = StockPriceDownloader('AAPL.O', '2022-01-01')
# Descargar datos
df_aapl = aapl.download_data()

df_aapl
# Out:
# ...
# Successfully downloaded 1036 records
# AAPL.O       Close    Open    High     Low     Volume
# Date
# 2022-01-03  182.01  177.83  182.88  177.71  104701220
# 2022-01-04   179.7  182.63  182.94  179.12   99310438
# 2022-01-05  174.92  179.61  180.17  174.64   94537602
# 2022-01-06   172.0   172.7   175.3  171.64   96903955
# 2022-01-07  172.17  172.89  174.14  171.03   86709147
# ...            ...     ...     ...     ...        ...
# 2026-02-12  261.73  275.59  275.72  260.18   81077229
# 2026-02-13  255.78  262.01  262.23  255.45   56290673
# 2026-02-17  263.88  258.05  266.29  255.54   58469094
# 2026-02-18  264.35   263.6  266.82  262.45   34203337
# 2026-02-19  260.58   262.6  264.48  260.05   30412027
#
# [1036 rows x 5 columns]

# %%
aapl.plot_closing_prices()

# %%
# Crear instancia
amzn = StockPriceDownloader('AMZN.O', '2022-01-01')
# Descargar datos
df_amzn = amzn.download_data()

df_amzn
# Out:
# ...
# Successfully downloaded 1036 records
# AMZN.O         Close      Open       High        Low    Volume
# Date
# 2022-01-03  170.4045    167.55   170.7035   166.1605  63869139
# 2022-01-04   167.522   170.438      171.4   166.3495  70725159
# 2022-01-05   164.357   166.883  167.12625    164.357  64302719
# 2022-01-06   163.254  163.4505      164.8  161.93721  51957779
# 2022-01-07   162.554   163.839  165.24325    162.031  46605899
# ...              ...       ...        ...        ...       ...
# 2026-02-12     199.6    203.96     203.96     197.56  83975393
# 2026-02-13    198.79    198.88     201.16    197.275  66321593
# 2026-02-17    201.15   198.125   201.7362      196.0  69879200
# 2026-02-18    204.79    202.07     206.86     201.51  51003299
# 2026-02-19    204.86     203.8   205.6396     202.81  35327222
#
# [1036 rows x 5 columns]

# %%
amzn.plot_closing_prices()
